# %%
import pandas as pd


data_conf = pd.read_json("dtype_conf.json")
data_conf
# Out:
#                     columnName               decode                source  \
# 0                       pushes               Pushes  clickhousePlayground
# 1                avg_push_size      Ср. размер push  clickhousePlayground
# 2                pull_requests        Pull requests  clickhousePlayground
# 3   merged_pull_requests_ratio    Слитых PR ко всем  clickhousePlayground
# 4                       issues               Issues  clickhousePlayground
# 5          closed_issues_ratio  Закр. issue ко всем  clickhousePlayground
# 6                      watches              Watches  clickhousePlayground
# 7                        forks                Forks  clickhousePlayground
# 8                  new_members          Новых уч-ов  clickhousePlayground
# 9                     language                 Язык             githubApi
# 10                license_name               Лиц-ия             githubApi
# 11       is_deleted_or_private    Удален или закрыт             githubApi
#
#     dtype  decimalPlaces
# 0     int            0.0
# 1   float            2.0
# 2     int            0.0
# 3   float            2.0
# 4     int            0.0
# 5   float            2.0
# 6     int            0.0
# 7     int            0.0
# 8     int            0.0
# 9     str            NaN
# 10    str            NaN
# 11    str            NaN

# %%
[col for col in  data_conf["columnName"]]
# Out:
# ['pushes',
#  'avg_push_size',
#  'pull_requests',
#  'merged_pull_requests_ratio',
#  'issues',
#  'closed_issues_ratio',
#  'watches',
#  'forks',
#  'new_members',
#  'language',
#  'license_name',
#  'is_deleted_or_private']

# %%
import pandas as pd
import numpy as np


# Загрузка данных
df = pd.read_csv("data/clickhouse_demo_github_events_data.csv")
df.head()
# Out:
# C:\Users\santiperro\AppData\Local\Temp\ipykernel_18652\2666831530.py:6: DtypeWarning: Columns (8,9,12,14,16,20,26,29,30,31,32,37,44,46,47,50,51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/clickhouse_demo_github_events_data.csv")
#              file_time          event_type  actor_login  \
# 0  2023-04-04 04:00:00  CommitCommentEvent  vercel[bot]
# 1  2023-04-04 06:00:00  CommitCommentEvent  vercel[bot]
# 2  2023-04-04 09:00:00  CommitCommentEvent  vercel[bot]
# 3  2023-04-04 09:00:00  CommitCommentEvent  vercel[bot]
# 4  2023-04-05 01:00:00  CommitCommentEvent  vercel[bot]
#
#                repo_name           created_at           updated_at action  \
# 0  OliverSpeir/portfolio  2023-04-04 04:59:04  2023-04-04 04:59:04   none
# 1  OliverSpeir/portfolio  2023-04-04 06:41:53  2023-04-04 06:41:53   none
# 2  OliverSpeir/portfolio  2023-04-04 09:12:00  2023-04-04 09:12:00   none
# 3  OliverSpeir/portfolio  2023-04-04 09:28:19  2023-04-04 09:28:19   none
# 4  OliverSpeir/portfolio  2023-04-05 01:18:56  2023-04-05 01:18:56   none
#
#     comment_id                                               body path  ...  \
# 0  107427595.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 1  107437214.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 2  107455321.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 3  107457449.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 4  107577128.0  Successfully deployed to the following URLs:\n...  NaN  ...
#
#    diff_hunk  original_position                                 commit_id  \
# 0        NaN                0.0  a12a8717acc6cc9aee74d8ac9ccf640ab6d134c0
# 1        NaN                0.0  a411023e71d64d5f25d0c2e9d5162fde41069381
# 2        NaN                0.0  d694b709ffec7fdafe31ca986db8ecae9ba10494
# 3        NaN                0.0  b9d72c03c82e541260a29a8c8ecce59d8538f847
# 4        NaN                0.0  32f96a4f1d84ec21782ac17110d975327bfd59b0
#
#   original_commit_id push_size  push_distinct_size member_login  \
# 0                NaN       0.0                 0.0          NaN
# 1                NaN       0.0                 0.0          NaN
# 2                NaN       0.0                 0.0          NaN
# 3                NaN       0.0                 0.0          NaN
# 4                NaN       0.0                 0.0          NaN
#
#   release_tag_name release_name  review_state
# 0              NaN          NaN          none
# 1              NaN          NaN          none
# 2              NaN          NaN          none
# 3              NaN          NaN          none
# 4              NaN          NaN          none
#
# [5 rows x 54 columns]

# %%
df[df["event_type"] == "MemberEvent"]['action']
# Out:
# 191495    added
# 191496    added
# 191497    added
# 191498    added
# 191499    added
#           ...
# 204881    added
# 204882    added
# 204883    added
# 204884    added
# 204885    added
# Name: action, Length: 13391, dtype: object

# %%
# Размерность данных
df.shape
# Out:
# (311070, 54)

# %%
# Столбцы
df.columns
# Out:
# Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#        'updated_at', 'action', 'comment_id', 'body', 'path', 'position',
#        'line', 'ref', 'ref_type', 'creator_user_login', 'number', 'title',
#        'labels', 'state', 'locked', 'assignee', 'assignees', 'comments',
#        'author_association', 'closed_at', 'merged_at', 'merge_commit_sha',
#        'requested_reviewers', 'requested_teams', 'head_ref', 'head_sha',
#        'base_ref', 'base_sha', 'merged', 'mergeable', 'rebaseable',
#        'mergeable_state', 'merged_by', 'review_comments',
#        'maintainer_can_modify', 'commits', 'additions', 'deletions',
#        'changed_files', 'diff_hunk', 'original_position', 'commit_id',
#        'original_commit_id', 'push_size', 'push_distinct_size', 'member_login',
#        'release_tag_name', 'release_name', 'review_state'],
#       dtype='object')

# %%
# Обработка пустых значений и дубликатов

df.drop_duplicates(inplace=True)

df.replace('none', np.nan, inplace=True)
df.replace('[]', np.nan, inplace=True)
df.replace('NONE', np.nan, inplace=True)
df.replace('1970-01-01 00:00:00', np.nan, inplace=True)

df[["comment_id", "push_size", "push_distinct_size"]] = df[["comment_id", "push_size", "push_distinct_size"]].replace(0, np.nan)

filter1 = ~df["event_type"].isin(["CommitCommentEvent", "PullRequestReviewCommentEvent"])
df.loc[filter1, "position"] = df.loc[filter1, "position"].replace(0, np.nan)
df.loc[filter1, "line"] = df.loc[filter1, "line"].replace(0, np.nan)

filter2 = ~df["event_type"].isin(['Event', 'IssueCommentEvent', 'IssuesEvent', 'PullRequestEvent', 'PullRequestReviewCommentEvent', 'PullRequestReviewEvent'])
df.loc[filter2, "number"] = df.loc[filter2, "number"].replace(0, np.nan)

filter3 = ~df["event_type"].isin(['IssueCommentEvent', 'IssuesEvent', 'PullRequestEvent'])
df.loc[filter3, "comments"] = df.loc[filter3, "comments"].replace(0, np.nan)

filter4 = ~df["event_type"].isin(["PullRequestEvent"])
df.loc[filter4, "merged"] = df.loc[filter4, "merged"].replace(0, np.nan)
df.loc[filter4, "mergeable"] = df.loc[filter4, "mergeable"].replace(0, np.nan)
df.loc[filter4, "mergeable_state"] = df.loc[filter4, "mergeable_state"].replace('unknown', np.nan)
df.loc[filter4, "review_comments"] = df.loc[filter4, "review_comments"].replace(0, np.nan)
df.loc[filter4, "maintainer_can_modify"] = df.loc[filter4, "maintainer_can_modify"].replace(0, np.nan)
df.loc[filter4, "rebaseable"] = df.loc[filter4, "rebaseable"].replace(0, np.nan)
df.loc[filter4, "changed_files"] = df.loc[filter4, "changed_files"].replace(0, np.nan)

filter5 = ~df["event_type"].isin(['Event', 'PullRequestEvent'])
df.loc[filter5, "commits"] = df.loc[filter5, "commits"].replace(0, np.nan)
df.loc[filter5, "additions"] = df.loc[filter5, "additions"].replace(0, np.nan)
df.loc[filter5, "deletions"] = df.loc[filter5, "deletions"].replace(0, np.nan)

filter6 = ~df["event_type"].isin(["PullRequestReviewCommentEvent"])
df.loc[filter6, "original_position"] = df.loc[filter6, "original_position"].replace(0, np.nan)

filter7 = ~df["event_type"].isin(['IssuesEvent', 'PullRequestReviewEvent'])
df.loc[filter7, "locked"] = df.loc[filter7, "locked"].replace(0, np.nan)
# Out:
# C:\Users\santiperro\AppData\Local\Temp\ipykernel_19596\660124690.py:25: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[filter4, "mergeable_state"] = df.loc[filter4, "mergeable_state"].replace('unknown', np.nan)

# %%
# Количество записей каждого события
df.groupby(by="event_type")["event_type"].count()
# Out:
# event_type
# CommitCommentEvent               11821
# CreateEvent                      13327
# DeleteEvent                      12593
# DownloadEvent                    17311
# Event                            32586
# FollowEvent                      35339
# ForkApplyEvent                    3216
# ForkEvent                        12404
# GistEvent                         7489
# GollumEvent                      15193
# IssueCommentEvent                11134
# IssuesEvent                      13041
# MemberEvent                      13387
# PublicEvent                      12355
# PullRequestEvent                  9617
# PullRequestReviewCommentEvent     8835
# PullRequestReviewEvent            9695
# PushEvent                        10809
# ReleaseEvent                     16534
# TeamAddEvent                     17180
# WatchEvent                       18302
# Name: event_type, dtype: int64

# %%
# Убирем устаревшие события
# Самая поздняя дата PublicEvent из целого датасета - 2017 год
# Event - 2011
# GistEvent - 2014
# DownloadEvent	- 2013
# FollowEvent - 2017
# ForkApplyEvent - 2012
# TeamAddEvent - 2014
# Нету SponsorshipEvent вообще

events = ['CommitCommentEvent', 
          'CreateEvent', 
          'DeleteEvent',
          'ForkEvent', 
          'GollumEvent', 
          'IssueCommentEvent',
          'IssuesEvent', 
          'MemberEvent', 
          'PullRequestEvent',
          'PullRequestReviewCommentEvent', 
          'PullRequestReviewEvent',
          'PushEvent',
          'ReleaseEvent', 
          'WatchEvent']

# %%
# Ненулевые столбцы по каждому событию

not_null_columns_by_events = {}

for event in events:
    not_null_columns_by_events[event] = df.columns[df[df["event_type"] == event].any()]

not_null_columns_by_events
# Out:
# {'CommitCommentEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'updated_at', 'comment_id', 'body', 'path', 'position', 'line',
#         'creator_user_login', 'commit_id'],
#        dtype='object'),
#  'CreateEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'ref', 'ref_type'],
#        dtype='object'),
#  'DeleteEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'ref', 'ref_type'],
#        dtype='object'),
#  'ForkEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at'], dtype='object'),
#  'GollumEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'action'],
#        dtype='object'),
#  'IssueCommentEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'updated_at', 'action', 'comment_id', 'body', 'creator_user_login',
#         'number', 'title', 'labels', 'state', 'assignee', 'assignees',
#         'comments', 'author_association', 'closed_at'],
#        dtype='object'),
#  'IssuesEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'updated_at', 'action', 'body', 'creator_user_login', 'number', 'title',
#         'labels', 'state', 'locked', 'assignee', 'assignees', 'comments',
#         'author_association', 'closed_at'],
#        dtype='object'),
#  'MemberEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'action', 'member_login'],
#        dtype='object'),
#  'PullRequestEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'updated_at', 'action', 'body', 'creator_user_login', 'number', 'title',
#         'labels', 'state', 'assignee', 'assignees', 'comments',
#         'author_association', 'closed_at', 'merged_at', 'merge_commit_sha',
#         'requested_reviewers', 'requested_teams', 'head_ref', 'head_sha',
#         'base_ref', 'base_sha', 'merged', 'mergeable', 'rebaseable',
#         'mergeable_state', 'merged_by', 'review_comments',
#         'maintainer_can_modify', 'commits', 'additions', 'deletions',
#         'changed_files'],
#        dtype='object'),
#  'PullRequestReviewCommentEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'updated_at', 'action', 'comment_id', 'body', 'path', 'position',
#         'line', 'creator_user_login', 'number', 'title', 'labels', 'state',
#         'assignee', 'assignees', 'author_association', 'closed_at', 'merged_at',
#         'merge_commit_sha', 'requested_reviewers', 'requested_teams',
#         'head_ref', 'head_sha', 'base_ref', 'base_sha', 'diff_hunk',
#         'original_position', 'commit_id', 'original_commit_id'],
#        dtype='object'),
#  'PullRequestReviewEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'updated_at', 'action', 'body', 'creator_user_login', 'number', 'title',
#         'labels', 'state', 'locked', 'assignee', 'assignees',
#         'author_association', 'closed_at', 'merged_at', 'merge_commit_sha',
#         'requested_reviewers', 'requested_teams', 'head_ref', 'head_sha',
#         'base_ref', 'base_sha', 'review_state'],
#        dtype='object'),
#  'PushEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'ref', 'push_size', 'push_distinct_size'],
#        dtype='object'),
#  'ReleaseEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'action', 'body', 'release_tag_name', 'release_name'],
#        dtype='object'),
#  'WatchEvent': Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#         'action'],
#        dtype='object')}

# %%
# Отделим данные каждого события друг от друга и отбросим ненужные столбцы

data_by_events = []

for event in not_null_columns_by_events.keys():
    data_by_events.append(df[df["event_type"] == event].dropna(axis=1, how="all"))

# %%
# Замыкание для удобного просмотра

def create_counter():
    count = 0
    def increment():
        nonlocal count
        if count < len(data_by_events) - 1:
            count += 1
        else:
            count = 0
        return count
    
    return increment

counter = create_counter()

# %%
# Используя замыкание, можно перезапускать ячейку для просмотра следующего события

data_by_events[counter()]
# Out:
#                   file_time         event_type    actor_login  \
# 167320  2011-04-08 11:00:00  IssueCommentEvent          zeevt
# 167321  2011-04-08 11:00:00  IssueCommentEvent        sellout
# 167322  2011-04-08 12:00:00  IssueCommentEvent   saintpajamas
# 167323  2011-04-08 12:00:00  IssueCommentEvent   saintpajamas
# 167324  2011-04-08 12:00:00  IssueCommentEvent   saintpajamas
# ...                     ...                ...            ...
# 178449  2018-08-05 23:00:00  IssueCommentEvent     codecov-io
# 178450  2018-08-06 06:00:00  IssueCommentEvent       xordoquy
# 178451  2018-08-06 08:00:00  IssueCommentEvent  carltongibson
# 178452  2018-08-06 08:00:00  IssueCommentEvent  carltongibson
# 178453  2018-08-06 09:00:00  IssueCommentEvent  carltongibson
#
#                            repo_name           created_at  \
# 167320                             /  2011-04-08 11:43:20
# 167321                             /  2011-04-08 11:56:03
# 167322                             /  2011-04-08 12:35:56
# 167323                             /  2011-04-08 12:52:05
# 167324                             /  2011-04-08 12:52:51
# ...                              ...                  ...
# 178449  encode/django-rest-framework  2018-08-05 23:44:34
# 178450  encode/django-rest-framework  2018-08-06 06:05:34
# 178451  encode/django-rest-framework  2018-08-06 08:00:20
# 178452  encode/django-rest-framework  2018-08-06 08:11:12
# 178453  encode/django-rest-framework  2018-08-06 09:47:29
#
#                  updated_at   action   comment_id  \
# 167320                  NaN      NaN          NaN
# 167321                  NaN      NaN          NaN
# 167322                  NaN      NaN          NaN
# 167323                  NaN      NaN          NaN
# 167324                  NaN      NaN          NaN
# ...                     ...      ...          ...
# 178449  2018-08-05 23:44:34  created  410557019.0
# 178450  2018-08-06 06:05:34  created  410598418.0
# 178451  2018-08-06 08:00:20  created  410621956.0
# 178452  2018-08-06 08:11:12  created  410624805.0
# 178453  2018-08-06 09:47:29  created  410651925.0
#
#                                                      body creator_user_login  \
# 167320                                                NaN                NaN
# 167321                                                NaN                NaN
# 167322                                                NaN                NaN
# 167323                                                NaN                NaN
# 167324                                                NaN                NaN
# ...                                                   ...                ...
# 178449  # [Codecov](https://codecov.io/gh/encode/djang...         codecov-io
# 178450  I don't see the reason for CSRF token for unau...           xordoquy
# 178451  Hi @ola-t: Sorry, this dropped off my radar in...      carltongibson
# 178452  In general we'd try to avoid adding additional...      carltongibson
# 178453  > Alternative solution is to use `Model._defau...      carltongibson
#
#         number                                              title labels  \
# 167320     0.0                                                NaN    NaN
# 167321     0.0                                                NaN    NaN
# 167322     0.0                                                NaN    NaN
# 167323     0.0                                                NaN    NaN
# 167324     0.0                                                NaN    NaN
# ...        ...                                                ...    ...
# 178449  6109.0                Test using Django 2.1 final release    NaN
# 178450  6104.0  SessionAuthentication, TokenAuthentication and...    NaN
# 178451  6074.0            reverse() escapes unreserved characters    NaN
# 178452  6108.0                      add feature: extra_validators    NaN
# 178453  6111.0  Handle models without .objects manager in Mode...    NaN
#
#          state assignee assignees  comments author_association  \
# 167320     NaN      NaN       NaN       0.0                NaN
# 167321     NaN      NaN       NaN       0.0                NaN
# 167322     NaN      NaN       NaN       0.0                NaN
# 167323     NaN      NaN       NaN       0.0                NaN
# 167324     NaN      NaN       NaN       0.0                NaN
# ...        ...      ...       ...       ...                ...
# 178449    open      NaN       NaN       0.0        CONTRIBUTOR
# 178450    open      NaN       NaN       3.0                NaN
# 178451  closed      NaN       NaN       8.0                NaN
# 178452  closed      NaN       NaN       1.0                NaN
# 178453    open      NaN       NaN       0.0                NaN
#
#                   closed_at
# 167320                  NaN
# 167321                  NaN
# 167322                  NaN
# 167323                  NaN
# 167324                  NaN
# ...                     ...
# 178449                  NaN
# 178450                  NaN
# 178451  2018-07-09 09:31:00
# 178452  2018-08-06 08:11:12
# 178453                  NaN
#
# [11134 rows x 19 columns]

# %%
df[df["event_type"] == "PullRequestReviewEvent"].iloc[1000]
# Out:
# file_time                                              2023-05-05 08:00:00
# event_type                                          PullRequestReviewEvent
# actor_login                                                         wegank
# repo_name                                                    NixOS/nixpkgs
# created_at                                             2023-05-05 08:07:37
# updated_at                                             2023-05-05 08:07:37
# action                                                             created
# comment_id                                                             NaN
# body                     ###### Description of changes\r\n\r\nhttps://g...
# path                                                                   NaN
# position                                                               NaN
# line                                                                   NaN
# ref                                                                    NaN
# ref_type                                                               NaN
# creator_user_login                                                 discite
# number                                                            229950.0
# title                                         cryptomator: 1.6.14 -> 1.8.0
# labels                   ["10.rebuild-linux: 1-10","10.rebuild-darwin: ...
# state                                                                 open
# locked                                                                 0.0
# assignee                                                               NaN
# assignees                                                              NaN
# comments                                                               NaN
# author_association                                                  MEMBER
# closed_at                                                              NaN
# merged_at                                                              NaN
# merge_commit_sha                  752d3840cbe53da5eb72090dc4cb122ffe7551b4
# requested_reviewers                                              ["bachp"]
# requested_teams                                                        NaN
# head_ref                                                            master
# head_sha                          1decf33de04719761bb8f5c1576efe2a9985ca8e
# base_ref                                                            master
# base_sha                          fed0618057e5714b2eb0b88bedbe671ce057a41a
# merged                                                                 NaN
# mergeable                                                              NaN
# rebaseable                                                             NaN
# mergeable_state                                                        NaN
# merged_by                                                              NaN
# review_comments                                                        NaN
# maintainer_can_modify                                                  NaN
# commits                                                                NaN
# additions                                                              NaN
# deletions                                                              NaN
# changed_files                                                          NaN
# diff_hunk                                                              NaN
# original_position                                                      NaN
# commit_id                                                              NaN
# original_commit_id                                                     NaN
# push_size                                                              NaN
# push_distinct_size                                                     NaN
# member_login                                                           NaN
# release_tag_name                                                       NaN
# release_name                                                           NaN
# review_state                                                     commented
# Name: 236767, dtype: object
