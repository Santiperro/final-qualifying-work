# %%
import pandas as pd


df = pd.read_csv("github_events_data.csv")
df.head()
# Out:
# C:\Users\santiperro\AppData\Local\Temp\ipykernel_15564\955709133.py:4: DtypeWarning: Columns (8,9,12,14,16,20,26,29,30,31,32,37,44,46,47,50,51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("github_events_data.csv")
#              file_time          event_type  actor_login  \
# 0  2023-04-04 04:00:00  CommitCommentEvent  vercel[bot]
# 1  2023-04-04 06:00:00  CommitCommentEvent  vercel[bot]
# 2  2023-04-04 09:00:00  CommitCommentEvent  vercel[bot]
# 3  2023-04-04 09:00:00  CommitCommentEvent  vercel[bot]
# 4  2023-04-05 01:00:00  CommitCommentEvent  vercel[bot]
#
#                repo_name           created_at           updated_at action  \
# 0  OliverSpeir/portfolio  2023-04-04 04:59:04  2023-04-04 04:59:04   none
# 1  OliverSpeir/portfolio  2023-04-04 06:41:53  2023-04-04 06:41:53   none
# 2  OliverSpeir/portfolio  2023-04-04 09:12:00  2023-04-04 09:12:00   none
# 3  OliverSpeir/portfolio  2023-04-04 09:28:19  2023-04-04 09:28:19   none
# 4  OliverSpeir/portfolio  2023-04-05 01:18:56  2023-04-05 01:18:56   none
#
#     comment_id                                               body path  ...  \
# 0  107427595.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 1  107437214.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 2  107455321.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 3  107457449.0  Successfully deployed to the following URLs:\n...  NaN  ...
# 4  107577128.0  Successfully deployed to the following URLs:\n...  NaN  ...
#
#    diff_hunk  original_position                                 commit_id  \
# 0        NaN                0.0  a12a8717acc6cc9aee74d8ac9ccf640ab6d134c0
# 1        NaN                0.0  a411023e71d64d5f25d0c2e9d5162fde41069381
# 2        NaN                0.0  d694b709ffec7fdafe31ca986db8ecae9ba10494
# 3        NaN                0.0  b9d72c03c82e541260a29a8c8ecce59d8538f847
# 4        NaN                0.0  32f96a4f1d84ec21782ac17110d975327bfd59b0
#
#   original_commit_id push_size  push_distinct_size member_login  \
# 0                NaN       0.0                 0.0          NaN
# 1                NaN       0.0                 0.0          NaN
# 2                NaN       0.0                 0.0          NaN
# 3                NaN       0.0                 0.0          NaN
# 4                NaN       0.0                 0.0          NaN
#
#   release_tag_name release_name  review_state
# 0              NaN          NaN          none
# 1              NaN          NaN          none
# 2              NaN          NaN          none
# 3              NaN          NaN          none
# 4              NaN          NaN          none
#
# [5 rows x 54 columns]

# %%
df.groupby(by="event_type")["event_type"].count()
# Out:
# event_type
# CommitCommentEvent               11821
# CreateEvent                      13327
# DeleteEvent                      12593
# DownloadEvent                    17311
# Event                            32586
# FollowEvent                      36045
# ForkApplyEvent                    3216
# ForkEvent                        12404
# GistEvent                         7489
# GollumEvent                      15228
# IssueCommentEvent                11134
# IssuesEvent                      13041
# MemberEvent                      13391
# PublicEvent                      12355
# PullRequestEvent                  9617
# PullRequestReviewCommentEvent     8836
# PullRequestReviewEvent           10280
# PushEvent                        10852
# ReleaseEvent                     16536
# TeamAddEvent                     17180
# WatchEvent                       18302
# Name: event_type, dtype: int64

# %%
df.columns
# Out:
# Index(['file_time', 'event_type', 'actor_login', 'repo_name', 'created_at',
#        'updated_at', 'action', 'comment_id', 'body', 'path', 'position',
#        'line', 'ref', 'ref_type', 'creator_user_login', 'number', 'title',
#        'labels', 'state', 'locked', 'assignee', 'assignees', 'comments',
#        'author_association', 'closed_at', 'merged_at', 'merge_commit_sha',
#        'requested_reviewers', 'requested_teams', 'head_ref', 'head_sha',
#        'base_ref', 'base_sha', 'merged', 'mergeable', 'rebaseable',
#        'mergeable_state', 'merged_by', 'review_comments',
#        'maintainer_can_modify', 'commits', 'additions', 'deletions',
#        'changed_files', 'diff_hunk', 'original_position', 'commit_id',
#        'original_commit_id', 'push_size', 'push_distinct_size', 'member_login',
#        'release_tag_name', 'release_name', 'review_state'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311070 entries, 0 to 311069
# Data columns (total 54 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   file_time              303544 non-null  object
#  1   event_type             303544 non-null  object
#  2   actor_login            301008 non-null  object
#  3   repo_name              303544 non-null  object
#  4   created_at             303544 non-null  object
#  5   updated_at             303544 non-null  object
#  6   action                 303544 non-null  object
#  7   comment_id             303544 non-null  float64
#  8   body                   58983 non-null   object
#  9   path                   10085 non-null   object
#  10  position               303544 non-null  float64
#  11  line                   303544 non-null  float64
#  12  ref                    52396 non-null   object
#  13  ref_type               303544 non-null  object
#  14  creator_user_login     61186 non-null   object
#  15  number                 303544 non-null  float64
#  16  title                  50398 non-null   object
#  17  labels                 303544 non-null  object
#  18  state                  303544 non-null  object
#  19  locked                 303544 non-null  float64
#  20  assignee               5581 non-null    object
#  21  assignees              303544 non-null  object
#  22  comments               303544 non-null  float64
#  23  author_association     303544 non-null  object
#  24  closed_at              303544 non-null  object
#  25  merged_at              303544 non-null  object
#  26  merge_commit_sha       22112 non-null   object
#  27  requested_reviewers    303544 non-null  object
#  28  requested_teams        303544 non-null  object
#  29  head_ref               28585 non-null   object
#  30  head_sha               28585 non-null   object
#  31  base_ref               28585 non-null   object
#  32  base_sha               28585 non-null   object
#  33  merged                 303544 non-null  float64
#  34  mergeable              303544 non-null  float64
#  35  rebaseable             303544 non-null  float64
#  36  mergeable_state        303544 non-null  object
#  37  merged_by              2489 non-null    object
#  38  review_comments        303544 non-null  float64
#  39  maintainer_can_modify  303544 non-null  float64
#  40  commits                303544 non-null  float64
#  41  additions              303544 non-null  float64
#  42  deletions              303544 non-null  float64
#  43  changed_files          303544 non-null  float64
#  44  diff_hunk              8788 non-null    object
#  45  original_position      303544 non-null  float64
#  46  commit_id              19744 non-null   object
#  47  original_commit_id     8836 non-null    object
#  48  push_size              303544 non-null  float64
#  49  push_distinct_size     303544 non-null  float64
#  50  member_login           13614 non-null   object
#  51  release_tag_name       16536 non-null   object
#  52  release_name           15258 non-null   object
#  53  review_state           303544 non-null  object
# dtypes: float64(18), object(36)
# memory usage: 128.2+ MB

# %%
# Столбики для удаления
["comment_id", "body", "path", "position", "line", "ref", "number", "title", "merge_commit_sha", "head_ref", "head_sha", "base_ref", "base_sha", "diff_hunk"]

# Столбики с датой для удаления
["updated_at", "created_at", "closed_at", "merged_at",]

# %%
df["labels"].value_counts().sort_values(ascending=False)
# Out:
# labels
# []                                                                            290431
# ["dependencies"]                                                                2622
# ["enhancement"]                                                                  973
# ["bug"]                                                                          836
# ["question"]                                                                     471
#                                                                                ...
# ["Priorty","Started","Working on","Tedious issue","intermediate-advanced"]         1
# ["documentation","enhancement","good first issue","easy-intermediate"]             1
# ["good first issue","Located issue"]                                               1
# ["Intermediate issue","Tedious issue"]                                             1
# ["Bug","Critical","Fixed","Service: Similar Genomes"]                              1
# Name: count, Length: 1509, dtype: int64
